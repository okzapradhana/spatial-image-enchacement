# %%
import numpy as np
import matplotlib.pyplot as plt
import math

#Image Negative
def convertRGBToGrayLevel(img):
    Green = img[:,:,0]
    Red = img[:,:,1]
    Blue = img[:,:,2]
    #maxx = np.maximum(Red, Green, Blue)
    #minn = np.minimum(Red, Green, Blue)    
    #grayLevel = (maxx + minn)/2
    grayLevel = 0.21 * Red + 0.71 * Green + 0.07 * Blue
    arrayGrayLevel = np.array(grayLevel)
    print(grayLevel)
    return (grayLevel)


img = plt.imread("./Lenna.png")
gray = convertRGBToGrayLevel(img)
print(gray)
negative = 255 - gray
plt.imshow(gray)
plt.show()
# Out:
# [[0.77639216 0.77639216 0.7702353  ... 0.7957647  0.7525882  0.663098  ]
#  [0.77639216 0.77639216 0.7702353  ... 0.7957647  0.7525882  0.663098  ]
#  [0.77639216 0.77639216 0.7702353  ... 0.7957647  0.7525882  0.663098  ]
#  ...
#  [0.26517648 0.26517648 0.29431373 ... 0.5648627  0.55576473 0.5655686 ]
#  [0.26207843 0.26207843 0.31066665 ... 0.57772547 0.58466667 0.59827447]
#  [0.26207843 0.26207843 0.31066665 ... 0.57772547 0.58466667 0.59827447]]
# [[0.77639216 0.77639216 0.7702353  ... 0.7957647  0.7525882  0.663098  ]
#  [0.77639216 0.77639216 0.7702353  ... 0.7957647  0.7525882  0.663098  ]
#  [0.77639216 0.77639216 0.7702353  ... 0.7957647  0.7525882  0.663098  ]
#  ...
#  [0.26517648 0.26517648 0.29431373 ... 0.5648627  0.55576473 0.5655686 ]
#  [0.26207843 0.26207843 0.31066665 ... 0.57772547 0.58466667 0.59827447]
#  [0.26207843 0.26207843 0.31066665 ... 0.57772547 0.58466667 0.59827447]]

# %%
#Log Transformations
c = 100000000000

imgLog = plt.imread("Lenna.png")
print(imgLog[:,:,0])
#gray = convertRGBToGrayLevel(imgLog)
plt.imshow(gray)
plt.title("Ori image")
plt.show()

logTrans = c * np.log1p(gray)

log10Trans = 10 * np.log1p(gray)


plt.imshow(logTrans)
plt.title("C = 10")
plt.show()


plt.imshow(logTrans)
plt.title("C = 100000000000")
plt.show()
# Out:
# [[0.8862745  0.8862745  0.8745098  ... 0.9019608  0.8666667  0.78431374]
#  [0.8862745  0.8862745  0.8745098  ... 0.9019608  0.8666667  0.78431374]
#  [0.8862745  0.8862745  0.8745098  ... 0.9019608  0.8666667  0.78431374]
#  ...
#  [0.32941177 0.32941177 0.36078432 ... 0.6784314  0.6745098  0.69411767]
#  [0.32156864 0.32156864 0.3764706  ... 0.7019608  0.70980394 0.7254902 ]
#  [0.32156864 0.32156864 0.3764706  ... 0.7019608  0.70980394 0.7254902 ]]

# %%
#Power Law Transformations
c = 1
gamma = 10
gamma2 = 50

imgLaw = plt.imread("./mountain.jpeg")
#print(imgLaw[:,:,0])
gray = convertRGBToGrayLevel(imgLaw)
plt.imshow(gray)
plt.title("Original Image")
plt.show()

lawTrans1 = c * (gray**(gamma))
plt.imshow(lawTrans1)
plt.title("Gamma = 10")
plt.show()

lawTrans2 = c * (gray**(gamma2))
plt.imshow(lawTrans2)
plt.title("Gamma = 50")
plt.show()
# Out:
# [[251.46 251.46 251.46 ... 107.38 108.37 109.43]
#  [251.46 251.46 251.46 ... 108.37 110.42 112.4 ]
#  [251.46 251.46 251.46 ... 109.08 108.94 112.9 ]
#  ...
#  [251.32 251.46 251.46 ... 184.1  198.88 224.62]
#  [251.32 251.46 251.46 ... 197.04 196.97 219.81]
#  [251.32 251.46 251.46 ... 205.1  200.01 214.79]]

# %%
#Piecewise Linear Transformations

imgPiecewise = plt.imread("./Lenna.png")
gray = convertRGBToGrayLevel(imgPiecewise)

maxGrayLevel = np.max(gray)

plt.imshow(gray)
plt.title("Original Image")
plt.show()



x = [0, 0.5, 0.5, 0.7, maxGrayLevel]
y = [0, 0.3, 0.3, 0.8, maxGrayLevel]

plt.plot(x, y)
plt.title("Grafik untuk Piecewise Linear")
plt.axis([0, 1, 0, 1])
plt.show()

gray[gray < x[1]] = 0
gray[(gray >= x[1]) & (gray <= x[3]) ] = 0.5
gray[gray > x[3]] = 1

plt.imshow(gray)
plt.title("Setelah dilakukan Piecewise Linear Transformations")
plt.show()
# Out:
# [[0.77639216 0.77639216 0.7702353  ... 0.7957647  0.7525882  0.663098  ]
#  [0.77639216 0.77639216 0.7702353  ... 0.7957647  0.7525882  0.663098  ]
#  [0.77639216 0.77639216 0.7702353  ... 0.7957647  0.7525882  0.663098  ]
#  ...
#  [0.26517648 0.26517648 0.29431373 ... 0.5648627  0.55576473 0.5655686 ]
#  [0.26207843 0.26207843 0.31066665 ... 0.57772547 0.58466667 0.59827447]
#  [0.26207843 0.26207843 0.31066665 ... 0.57772547 0.58466667 0.59827447]]

# %%
#Image Subtraction

imgSub1=plt.imread("dataset1.jpeg")
imgSub2=plt.imread("dataset2.jpeg")

def subtractOperation(rgb1,rgb2):
    subtract=rgb1-rgb2
    return (subtract)

#Original Picture 1
plt.imshow(imgSub1)
plt.show()
#Original Picture 2
plt.imshow(imgSub2)
plt.show()
plt.imshow(subtractOperation(imgSub1,imgSub2))
plt.show()

# %%
#Logical operations

#OR
imageMask = plt.imread("logicaloperations.png")
plt.imshow(imageMask)
plt.title("OR image Mask")
plt.show()

print(imageMask.shape)

oriImage = plt.imread("Lenna.png")
gray = convertRGBToGrayLevel(oriImage)
#plt.imshow(gray)
plt.imshow(oriImage)
plt.title("Original Image")
plt.show()

gray3d = np.stack([gray], axis=-1)
print(gray3d.shape)

ORLogicalImage = imageMask + oriImage

plt.imshow(ORLogicalImage)
plt.title("Setelah dilakukan OR Logical Image Operations")
plt.show()
# Out:
# (512, 512, 3)
# [[0.77639216 0.77639216 0.7702353  ... 0.7957647  0.7525882  0.663098  ]
#  [0.77639216 0.77639216 0.7702353  ... 0.7957647  0.7525882  0.663098  ]
#  [0.77639216 0.77639216 0.7702353  ... 0.7957647  0.7525882  0.663098  ]
#  ...
#  [0.26517648 0.26517648 0.29431373 ... 0.5648627  0.55576473 0.5655686 ]
#  [0.26207843 0.26207843 0.31066665 ... 0.57772547 0.58466667 0.59827447]
#  [0.26207843 0.26207843 0.31066665 ... 0.57772547 0.58466667 0.59827447]]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (512, 512, 1)

# %%
#AND

imageMask = plt.imread("logicaloperations.png")
plt.imshow(imageMask)
plt.title("AND image Mask")
plt.show()

print(imageMask.shape)

oriImage = plt.imread("Lenna.png")
gray = convertRGBToGrayLevel(oriImage)
#plt.imshow(gray)
plt.imshow(oriImage)
plt.title("Original Image")
plt.show()

#gray3d = np.stack([gray], axis=-1)
AndLogicalImage = imageMask * oriImage

plt.imshow(AndLogicalImage)
plt.title("Setelah dilakukan AND Logical Image Operations")
plt.show()
# Out:
# (512, 512, 3)
# [[0.77639216 0.77639216 0.7702353  ... 0.7957647  0.7525882  0.663098  ]
#  [0.77639216 0.77639216 0.7702353  ... 0.7957647  0.7525882  0.663098  ]
#  [0.77639216 0.77639216 0.7702353  ... 0.7957647  0.7525882  0.663098  ]
#  ...
#  [0.26517648 0.26517648 0.29431373 ... 0.5648627  0.55576473 0.5655686 ]
#  [0.26207843 0.26207843 0.31066665 ... 0.57772547 0.58466667 0.59827447]
#  [0.26207843 0.26207843 0.31066665 ... 0.57772547 0.58466667 0.59827447]]
